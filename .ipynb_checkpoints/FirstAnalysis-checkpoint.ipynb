# %% [markdown]
# This Jupyter Notebook provide the beginning of the treatment of the data. This will be useful for the whole project. \\
# First, we will wrangle the data. This section will form an intresting dataFrame that will allows us to master the data afterward.
# For the begining of the project, only the revenues of the movies will be useful as well as the character and their participation of the various films.

# %%
import pandas as pd
import numpy as np
import json
import sys
import requests

# %%
dataFrame_movie = pd.read_csv("Moviemovie.metadata.tsv",delimiter='\t') 
dataFrame_movie.columns = ['Wikipedia ID', 'Freebase ID', 'Name', 'Release Date', 'Revenue', 'Run Time', 'Language', 'Countries', 'Genres']

dataFrame_character = pd.read_csv("character.metadata.tsv",delimiter='\t') 
dataFrame_character.columns = ['Wikipedia ID', 'Freebase ID', 'Release Date', 'Character Name', 'Actor Birth', 'Actor Gender', 'Actor Height', 'Ethnicity', 'Actor Name', 'Actor Age At Movie Release', 'Freebase Actor/Character Map ID', 'Freebase Character ID', 'Freebase Actor ID']


display(dataFrame_movie)
# Out:
#        Wikipedia ID Freebase ID  \
# 0           3196793   /m/08yl5d
# 1          28463795  /m/0crgdbh
# 2           9363483  /m/0285_cd
# 3            261236   /m/01mrr1
# 4          13696889  /m/03cfc81
# ...             ...         ...
# 81735      35228177  /m/0j7hxnt
# 81736      34980460  /m/0g4pl34
# 81737       9971909  /m/02pygw1
# 81738        913762   /m/03pcrp
# 81739      12476867  /m/02w7zz8
#
#                                                     Name Release Date  \
# 0      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 1                                            Brun bitter         1988
# 2                                       White Of The Eye         1987
# 3                                      A Woman in Flames         1983
# 4                                          The Gangsters   1913-05-29
# ...                                                  ...          ...
# 81735                           Mermaids: The Body Found   2011-03-19
# 81736                                            Knuckle   2011-01-21
# 81737                                  Another Nice Mess   1972-09-22
# 81738  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 81739                                            Spliced         2002
#
#        Revenue  Run Time                                           Language  \
# 0          NaN      95.0                 {"/m/02h40lc": "English Language"}
# 1          NaN      83.0                 {"/m/05f_3": "Norwegian Language"}
# 2          NaN     110.0                 {"/m/02h40lc": "English Language"}
# 3          NaN     106.0                  {"/m/04306rv": "German Language"}
# 4          NaN      35.0  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# ...        ...       ...                                                ...
# 81735      NaN     120.0                 {"/m/02h40lc": "English Language"}
# 81736      NaN      96.0                 {"/m/02h40lc": "English Language"}
# 81737      NaN      66.0                 {"/m/02h40lc": "English Language"}
# 81738      NaN     150.0                  {"/m/03_9r": "Japanese Language"}
# 81739      NaN      86.0                 {"/m/02h40lc": "English Language"}
#
#                                                Countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1                                 {"/m/05b4w": "Norway"}
# 2                         {"/m/07ssc": "United Kingdom"}
# 3                                {"/m/0345h": "Germany"}
# 4              {"/m/09c7w0": "United States of America"}
# ...                                                  ...
# 81735          {"/m/09c7w0": "United States of America"}
# 81736  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81737          {"/m/09c7w0": "United States of America"}
# 81738                              {"/m/03_3d": "Japan"}
# 81739                            {"/m/0d060g": "Canada"}
#
#                                                   Genres
# 0      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 1      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 2      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 3                                {"/m/07s9rl0": "Drama"}
# 4      {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# ...                                                  ...
# 81735                            {"/m/07s9rl0": "Drama"}
# 81736  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81737       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81738  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81739  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81740 rows x 9 columns]

# %%
percentage_missing_values_revenues = (dataFrame_movie['Revenue'].isna().sum()/len(dataFrame_movie['Revenue']))*100
print(f"The percentage of missing values 'Box office' is {format(percentage_missing_values_revenues, '.3f')}%.")

#as we can see, there are a lot of missing values in the "Revenue" column
# Out:
# The percentage of missing values 'Box office' is 89.724%.

# %% [markdown]
# In the CMU movie dataset, there are movies that have the same Name but are different. Therefore, it is complicated to differentiate movies based on their names. To overcome this issue, we identified each movie by its Freebase ID or its IMDB ID (depending on the dataset). To do so, we first need to retreive the IMDB ID (i.e. tconst column) based on its Freebase ID.

# %%
# def get_wikidata_id_translations():
#     query = """
#     SELECT ?item ?imdbID ?freebaseID WHERE {
#       ?item wdt:P345 ?imdbID.
#       OPTIONAL {?item wdt:P646 ?freebaseID.}
#     }
  
#     """

#     url = 'https://query.wikidata.org/sparql'
#     headers = {'User-Agent': 'WDQS-example Python/%s.%s' % (sys.version_info[0], sys.version_info[1])}
#     data = requests.get(url, headers=headers, params={'query': query, 'format': 'json'}).json()
    
#     imdb_id = []
#     freebase_id = []
#     for item in data['results']['bindings']:
#         imdb_id.append(item['imdbID']['value'])
#         freebase_id_val = item.get('freebaseID', {}).get('value', None)
#         freebase_id.append(freebase_id_val)

#     return pd.DataFrame(data={'tconst': imdb_id, 'Freebase ID': freebase_id})

# # Usage
# df_id_translation = get_wikidata_id_translations()
# display(df_id_translation)

# # Optionally, you can save this DataFrame to a JSON file
# df_id_translation.to_json('id-translation.wikidata.json', orient='records', lines=True)

# %%
#replace 'id-translation.wikidata.json' with the path to your JSON file
file_path = 'id-translation.wikidata.json'

#load the JSON file into a DataFrame
df_id_translation = pd.read_json(file_path, orient='records', lines=True)

#display the loaded DataFrame
display(df_id_translation)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 file_path = 'id-translation.wikidata.json'
#       4 #load the JSON file into a DataFrame
# ----> 5 df_id_translation = pd.read_json(file_path, orient='records', lines=True)
#       7 #display the loaded DataFrame
#       8 display(df_id_translation)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/json/_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
#     762     orient=orient,
#     763     typ=typ,
#     764     dtype=dtype,
#     765     convert_axes=convert_axes,
#     766     convert_dates=convert_dates,
#     767     keep_default_dates=keep_default_dates,
#     768     precise_float=precise_float,
#     769     date_unit=date_unit,
#     770     encoding=encoding,
#     771     lines=lines,
#     772     chunksize=chunksize,
#     773     compression=compression,
#     774     nrows=nrows,
#     775     storage_options=storage_options,
#     776     encoding_errors=encoding_errors,
#     777     dtype_backend=dtype_backend,
#     778     engine=engine,
#     779 )
#     781 if chunksize:
#     782     return json_reader
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/json/_json.py:861, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     859     self.data = filepath_or_buffer
#     860 elif self.engine == "ujson":
# --> 861     data = self._get_data_from_filepath(filepath_or_buffer)
#     862     self.data = self._preprocess_data(data)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/json/_json.py:917, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     909     filepath_or_buffer = self.handles.handle
#     910 elif (
#     911     isinstance(filepath_or_buffer, str)
#     912     and filepath_or_buffer.lower().endswith(
#    (...)
#     915     and not file_exists(filepath_or_buffer)
#     916 ):
# --> 917     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     919 return filepath_or_buffer
#
# FileNotFoundError: File id-translation.wikidata.json does not exist

# %%
df_id_translation = df_id_translation.dropna(subset=['Freebase ID'])
#df_id_translation.drop_duplicates(subset=['Freebase ID'], keep='first', inplace=True)
print(df_id_translation.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_id_translation = df_id_translation.dropna(subset=['Freebase ID'])
#       2 #df_id_translation.drop_duplicates(subset=['Freebase ID'], keep='first', inplace=True)
#       3 print(df_id_translation.shape)
#
# NameError: name 'df_id_translation' is not defined

# %%
df_id_translation.drop_duplicates(subset=['Freebase ID'], keep='first', inplace=True)
print(df_id_translation.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_id_translation.drop_duplicates(subset=['Freebase ID'], keep='first', inplace=True)
#       2 print(df_id_translation.shape)
#
# NameError: name 'df_id_translation' is not defined

# %%
dataFrame_movie = pd.merge(dataFrame_movie, df_id_translation, on='Freebase ID', how='left')
display(dataFrame_movie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dataFrame_movie = pd.merge(dataFrame_movie, df_id_translation, on='Freebase ID', how='left')
#       2 display(dataFrame_movie)
#
# NameError: name 'df_id_translation' is not defined

# %%
##load additionnal dataset
df_kaggle_movie = pd.read_csv("../movies_metadata.csv", sep=',', header=0, low_memory=False)
df_kaggle_movie.rename(columns={'title': 'Name', 'revenue': 'Revenue', 'id': 'movieId', 'release_date': 'Release date', 'imdb_id': 'tconst'}, inplace=True)
#df_kaggle_movie['Revenue'] = df_kaggle_movie['Revenue'].replace(0, np.nan)
display(df_kaggle_movie)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 ##load additionnal dataset
# ----> 2 df_kaggle_movie = pd.read_csv("../movies_metadata.csv", sep=',', header=0, low_memory=False)
#       3 df_kaggle_movie.rename(columns={'title': 'Name', 'revenue': 'Revenue', 'id': 'movieId', 'release_date': 'Release date', 'imdb_id': 'tconst'}, inplace=True)
#       4 #df_kaggle_movie['Revenue'] = df_kaggle_movie['Revenue'].replace(0, np.nan)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../movies_metadata.csv'

# %%
#merging the two datasets
dataFrame_movie = dataFrame_movie.merge(df_kaggle_movie[['Name', 'tconst', 'Revenue']], on=['Name', 'tconst'], how='left', suffixes=('', '_df2'))

#use 'combine_first' to fill in the 'Revenue' values from df_kaggle_movie where they are NaN in df_movie
dataFrame_movie['Revenue'] = dataFrame_movie['Revenue'].combine_first(dataFrame_movie['Revenue_df2'])

#drop the 'Revenue_df2' column
dataFrame_movie.drop('Revenue_df2', axis=1, inplace=True)

#drop duplicates
dataFrame_movie = dataFrame_movie.drop_duplicates(subset='Wikipedia ID', keep='first')
display(dataFrame_movie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 #merging the two datasets
# ----> 2 dataFrame_movie = dataFrame_movie.merge(df_kaggle_movie[['Name', 'tconst', 'Revenue']], on=['Name', 'tconst'], how='left', suffixes=('', '_df2'))
#       4 #use 'combine_first' to fill in the 'Revenue' values from df_kaggle_movie where they are NaN in df_movie
#       5 dataFrame_movie['Revenue'] = dataFrame_movie['Revenue'].combine_first(dataFrame_movie['Revenue_df2'])
#
# NameError: name 'df_kaggle_movie' is not defined

# %%
percentage_missing_values_revenues = (dataFrame_movie['Revenue'].isna().sum()/len(dataFrame_movie['Revenue']))*100
print(f"The percentage of missing values 'Box office' is {format(percentage_missing_values_revenues, '.3f')}%.")
# Out:
# The percentage of missing values 'Box office' is 89.724%.

# %% [markdown]
# We have now our 2 dataframes. First, We will drop the NA in the revenue. We need to have the revenues of the movie we are working with.

# %%
dataFrame_movie = dataFrame_movie.dropna(subset=['Revenue'])

# %% [markdown]
# First, we are counting the number of actor per film (actor = character)

# %%
df_count = dataFrame_movie.merge(dataFrame_character, on = 'Wikipedia ID', how = 'left') # POPULATE EACH MOVIE WITH ACTOR 
counter = df_count.groupby('Wikipedia ID')['Actor Name'].nunique() # We count the number of actor per movie

# %%
df_count
# Out:
#         Wikipedia ID Freebase ID_x                      Name Release Date_x  \
# 0           10408933    /m/02qc0j7  Alexander's Ragtime Band     1938-08-16
# 1           10408933    /m/02qc0j7  Alexander's Ragtime Band     1938-08-16
# 2           10408933    /m/02qc0j7  Alexander's Ragtime Band     1938-08-16
# 3           10408933    /m/02qc0j7  Alexander's Ragtime Band     1938-08-16
# 4             171005     /m/016ywb                   Henry V     1989-11-08
# ...              ...           ...                       ...            ...
# 101184        664006     /m/030xw6             Guilty as Sin     1993-06-04
# 101185        664006     /m/030xw6             Guilty as Sin     1993-06-04
# 101186        664006     /m/030xw6             Guilty as Sin     1993-06-04
# 101187        664006     /m/030xw6             Guilty as Sin     1993-06-04
# 101188      26482675    /m/0bbwngb            Eşrefpaşalılar     2010-03-05
#
#            Revenue  Run Time                            Language  \
# 0        3600000.0     106.0  {"/m/02h40lc": "English Language"}
# 1        3600000.0     106.0  {"/m/02h40lc": "English Language"}
# 2        3600000.0     106.0  {"/m/02h40lc": "English Language"}
# 3        3600000.0     106.0  {"/m/02h40lc": "English Language"}
# 4       10161099.0     137.0  {"/m/02h40lc": "English Language"}
# ...            ...       ...                                 ...
# 101184  22886222.0     107.0                                  {}
# 101185  22886222.0     107.0                                  {}
# 101186  22886222.0     107.0                                  {}
# 101187  22886222.0     107.0                                  {}
# 101188   1847671.0       NaN                                  {}
#
#                                         Countries  \
# 0       {"/m/09c7w0": "United States of America"}
# 1       {"/m/09c7w0": "United States of America"}
# 2       {"/m/09c7w0": "United States of America"}
# 3       {"/m/09c7w0": "United States of America"}
# 4                  {"/m/07ssc": "United Kingdom"}
# ...                                           ...
# 101184  {"/m/09c7w0": "United States of America"}
# 101185  {"/m/09c7w0": "United States of America"}
# 101186  {"/m/09c7w0": "United States of America"}
# 101187  {"/m/09c7w0": "United States of America"}
# 101188                                         {}
#
#                                                    Genres Freebase ID_y  ...  \
# 0       {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...    /m/02qc0j7  ...
# 1       {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...    /m/02qc0j7  ...
# 2       {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...    /m/02qc0j7  ...
# 3       {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...    /m/02qc0j7  ...
# 4       {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...     /m/016ywb  ...
# ...                                                   ...           ...  ...
# 101184  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...     /m/030xw6  ...
# 101185  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...     /m/030xw6  ...
# 101186  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...     /m/030xw6  ...
# 101187  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...     /m/030xw6  ...
# 101188  {"/m/05p553": "Comedy film", "/m/07s9rl0": "Dr...    /m/0bbwngb  ...
#
#                    Character Name Actor Birth Actor Gender Actor Height  \
# 0                             NaN  1908-01-16            F          NaN
# 1       Roger Grant AKA Alexander  1914-05-05            M        1.820
# 2                             NaN  1915-05-05            F        1.650
# 3                             NaN  1908-05-31            M        1.791
# 4                         Henry V  1960-12-10            M        1.770
# ...                           ...         ...          ...          ...
# 101184                        NaN  1956-08-28            M        1.710
# 101185                        NaN  1920-09-18            M        1.790
# 101186                        NaN  1935-09-24            M          NaN
# 101187                        NaN  1959-03-08            F          NaN
# 101188                        NaN        1973            M          NaN
#
#          Ethnicity          Actor Name Actor Age At Movie Release  \
# 0              NaN        Ethel Merman                       30.0
# 1        /m/06v41q        Tyrone Power                       24.0
# 2        /m/033tf_          Alice Faye                       23.0
# 3              NaN          Don Ameche                       30.0
# 4         /m/0d7wh     Kenneth Branagh                       28.0
# ...            ...                 ...                        ...
# 101184   /m/0gkxl2         Luis Guzmán                       36.0
# 101185         NaN         Jack Warden                       72.0
# 101186  /m/044038p         Sean McCann                       57.0
# 101187         NaN  Barbara Eve Harris                       34.0
# 101188         NaN      Sinan Albayrak                       37.0
#
#         Freebase Actor/Character Map ID Freebase Character ID  \
# 0                            /m/02vctvm                   NaN
# 1                            /m/02vbvj2            /m/0h36wrs
# 2                            /m/02vbq8t                   NaN
# 3                            /m/02vbjy4                   NaN
# 4                             /m/0jzbqf            /m/02nw8cd
# ...                                 ...                   ...
# 101184                       /m/0cgb0nt                   NaN
# 101185                       /m/0cg3s58                   NaN
# 101186                       /m/0cg1r2m                   NaN
# 101187                       /m/0gccw65                   NaN
# 101188                       /m/0hgtl12                   NaN
#
#        Freebase Actor ID
# 0               /m/0pkw7
# 1              /m/02s58t
# 2              /m/032xfz
# 3              /m/02l0xc
# 4               /m/0prjs
# ...                  ...
# 101184         /m/031f1q
# 101185         /m/02wr6r
# 101186         /m/06w_1w
# 101187         /m/0gsvr7
# 101188        /m/0c3x391
#
# [101189 rows x 21 columns]

# %%
import matplotlib.pyplot as plt


plt.hist(counter, bins =max(counter))

plt.title('Frequency of the Number of actor per movie')
plt.xlabel('Number of actor per movie')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Now, the idea is to create a matrix. Each row of the matrix represent a differente movie. Every Column represents a different actor. The matrix returns 1 if the actor i plays in the movie j and 0 otherwise

# %%
# Create a binary matrix where rows represent movies, columns represent actors
binary_matrix = df_count.pivot_table(index='Name', columns='Actor Name', aggfunc='size', fill_value=0)

# Reset the index to have movie name as a column
binary_matrix = binary_matrix.reset_index()

# Fill NaN values with 0 (if necessary)
binary_matrix = binary_matrix.fillna(0)

# Rename the columns with a prefix for clarity
binary_matrix.columns = ['Name'] + [ str(col) for col in binary_matrix.columns[1:]]

# Set 'movie name' as the index 
binary_matrix.set_index('Name', inplace=True)

# %%
binary_matrix
# Out:
#                          'Squeeks' the Caterpillar  40 Glocc  50 Cent  \
# Name
# 'Til There Was You                               0         0        0
# (500) Days of Summer                             0         0        0
# *batteries not included                          0         0        0
# ...And Justice for All                           0         0        0
# 10                                               0         0        0
# ...                                            ...       ...      ...
# Zoom                                             0         0        0
# Zoot Suit                                        0         0        0
# ¡Three Amigos!                                   0         0        0
# Æon Flux                                         0         0        0
# Žižek!                                           0         0        0
#
#                          A Martinez  A. Delon Ellis Jr.  A. J. Benza  \
# Name
# 'Til There Was You                0                   0            0
# (500) Days of Summer              0                   0            0
# *batteries not included           0                   0            0
# ...And Justice for All            0                   0            0
# 10                                0                   0            0
# ...                             ...                 ...          ...
# Zoom                              0                   0            0
# Zoot Suit                         0                   0            0
# ¡Three Amigos!                    0                   0            0
# Æon Flux                          0                   0            0
# Žižek!                            0                   0            0
#
#                          A. J. Bowen  A. J. Buckley  A. J. Cook  A. J. Langer  \
# Name
# 'Til There Was You                 0              0           0             0
# (500) Days of Summer               0              0           0             0
# *batteries not included            0              0           0             0
# ...And Justice for All             0              0           0             0
# 10                                 0              0           0             0
# ...                              ...            ...         ...           ...
# Zoom                               0              0           0             0
# Zoot Suit                          0              0           0             0
# ¡Three Amigos!                     0              0           0             0
# Æon Flux                           0              0           0             0
# Žižek!                             0              0           0             0
#
#                          ...  Þrúður Vilhjálmsdóttir  İdil Fırat  \
# Name                     ...
# 'Til There Was You       ...                       0           0
# (500) Days of Summer     ...                       0           0
# *batteries not included  ...                       0           0
# ...And Justice for All   ...                       0           0
# 10                       ...                       0           0
# ...                      ...                     ...         ...
# Zoom                     ...                       0           0
# Zoot Suit                ...                       0           0
# ¡Three Amigos!           ...                       0           0
# Æon Flux                 ...                       0           0
# Žižek!                   ...                       0           0
#
#                          İsmail Hacıoğlu  Şafak Sezer  Şebnem Dönmez  \
# Name
# 'Til There Was You                     0            0              0
# (500) Days of Summer                   0            0              0
# *batteries not included                0            0              0
# ...And Justice for All                 0            0              0
# 10                                     0            0              0
# ...                                  ...          ...            ...
# Zoom                                   0            0              0
# Zoot Suit                              0            0              0
# ¡Three Amigos!                         0            0              0
# Æon Flux                               0            0              0
# Žižek!                                 0            0              0
#
#                          Şener Şen  Şevval Sam  Željko Ivanek  佐々木望  田村英里子
# Name
# 'Til There Was You               0           0              0     0      0
# (500) Days of Summer             0           0              0     0      0
# *batteries not included          0           0              0     0      0
# ...And Justice for All           0           0              0     0      0
# 10                               0           0              0     0      0
# ...                            ...         ...            ...   ...    ...
# Zoom                             0           0              0     0      0
# Zoot Suit                        0           0              0     0      0
# ¡Three Amigos!                   0           0              0     0      0
# Æon Flux                         0           0              0     0      0
# Žižek!                           0           0              0     0      0
#
# [8022 rows x 37373 columns]

# %% [markdown]
# We have to much actor right now, therefore we have to get rid of many of them

# %% [markdown]
# Using this matrix, we will remove the actors that appears in less than 35 movies

# %%
actor_sum=binary_matrix.sum()
actors_to_drop=actor_sum[actor_sum<35].index

# %%
filtered_binary_matrix=binary_matrix.drop(actors_to_drop,axis=1)

# %%
filtered_binary_matrix
# Out:
#                          Adam Sandler  Alec Baldwin  Alfred Molina  \
# Name
# 'Til There Was You                  0             0              0
# (500) Days of Summer                0             0              0
# *batteries not included             0             0              0
# ...And Justice for All              0             0              0
# 10                                  0             0              0
# ...                               ...           ...            ...
# Zoom                                0             0              0
# Zoot Suit                           0             0              0
# ¡Three Amigos!                      0             0              0
# Æon Flux                            0             0              0
# Žižek!                              0             0              0
#
#                          Anjelica Huston  Anthony Hopkins  Antonio Banderas  \
# Name
# 'Til There Was You                     0                0                 0
# (500) Days of Summer                   0                0                 0
# *batteries not included                0                0                 0
# ...And Justice for All                 0                0                 0
# 10                                     0                0                 0
# ...                                  ...              ...               ...
# Zoom                                   0                0                 0
# Zoot Suit                              0                0                 0
# ¡Three Amigos!                         0                0                 0
# Æon Flux                               0                0                 0
# Žižek!                                 0                0                 0
#
#                          Ben Affleck  Ben Stiller  Bill Murray  Brad Pitt  \
# Name
# 'Til There Was You                 0            0            0          0
# (500) Days of Summer               0            0            0          0
# *batteries not included            0            0            0          0
# ...And Justice for All             0            0            0          0
# 10                                 0            0            0          0
# ...                              ...          ...          ...        ...
# Zoom                               0            0            0          0
# Zoot Suit                          0            0            0          0
# ¡Three Amigos!                     0            0            0          0
# Æon Flux                           0            0            0          0
# Žižek!                             0            0            0          0
#
#                          ...  Tom Hanks  Tom Wilkinson  Tommy Lee Jones  \
# Name                     ...
# 'Til There Was You       ...          0              0                0
# (500) Days of Summer     ...          0              0                0
# *batteries not included  ...          0              0                0
# ...And Justice for All   ...          0              0                0
# 10                       ...          0              0                0
# ...                      ...        ...            ...              ...
# Zoom                     ...          0              0                0
# Zoot Suit                ...          0              0                0
# ¡Three Amigos!           ...          0              0                0
# Æon Flux                 ...          0              0                0
# Žižek!                   ...          0              0                0
#
#                          Val Kilmer  Ving Rhames  Wallace Shawn  \
# Name
# 'Til There Was You                0            0              0
# (500) Days of Summer              0            0              0
# *batteries not included           0            0              0
# ...And Justice for All            0            0              0
# 10                                0            0              0
# ...                             ...          ...            ...
# Zoom                              0            0              0
# Zoot Suit                         0            0              0
# ¡Three Amigos!                    0            0              0
# Æon Flux                          0            0              0
# Žižek!                            0            0              0
#
#                          Whoopi Goldberg  Willem Dafoe  William H. Macy  \
# Name
# 'Til There Was You                     0             0                0
# (500) Days of Summer                   0             0                0
# *batteries not included                0             0                0
# ...And Justice for All                 0             0                0
# 10                                     0             0                0
# ...                                  ...           ...              ...
# Zoom                                   0             0                0
# Zoot Suit                              0             0                0
# ¡Three Amigos!                         0             0                0
# Æon Flux                               0             0                0
# Žižek!                                 0             0                0
#
#                          Woody Harrelson
# Name
# 'Til There Was You                     0
# (500) Days of Summer                   0
# *batteries not included                0
# ...And Justice for All                 0
# 10                                     0
# ...                                  ...
# Zoom                                   0
# Zoot Suit                              0
# ¡Three Amigos!                         0
# Æon Flux                               0
# Žižek!                                 0
#
# [8022 rows x 113 columns]

# %%
for i in filtered_binary_matrix.columns.tolist():
    print(i)
# Out:
# Adam Sandler
# Alec Baldwin
# Alfred Molina
# Anjelica Huston
# Anthony Hopkins
# Antonio Banderas
# Ben Affleck
# Ben Stiller
# Bill Murray
# Brad Pitt
# Brian Cox
# Bruce Willis
# Burt Reynolds
# Cheech Marin
# Christian Slater
# Christopher Lloyd
# Christopher Walken
# Clint Eastwood
# Dan Aykroyd
# Dan Hedaya
# Danny DeVito
# Danny Glover
# Dennis Hopper
# Dennis Quaid
# Denzel Washington
# Donald Sutherland
# Drew Barrymore
# Dustin Hoffman
# Ed Harris
# Eddie Murphy
# Eugene Levy
# Forest Whitaker
# Frank Welker
# Gary Oldman
# Gene Hackman
# Harrison Ford
# Harry Dean Stanton
# Harvey Keitel
# J. K. Simmons
# Jack Black
# Jack Nicholson
# Jack Warden
# James Cromwell
# James Earl Jones
# James Woods
# Jeff Bridges
# Jeff Daniels
# Jeffrey Tambor
# Jim Broadbent
# Jim Cummings
# Joan Cusack
# John C. Reilly
# John Cleese
# John Cusack
# John Goodman
# John Hurt
# John Leguizamo
# John Lithgow
# John Malkovich
# John Travolta
# John Turturro
# John Wayne
# Johnny Depp
# Julia Roberts
# Julianne Moore
# Kathy Bates
# Keith David
# Kevin Bacon
# Kevin Kline
# Kevin Spacey
# Kiefer Sutherland
# Laurence Fishburne
# Liam Neeson
# Luis Guzmán
# M. Emmet Walsh
# Mary Steenburgen
# Matt Damon
# Meryl Streep
# Michael Caine
# Michelle Pfeiffer
# Morgan Freeman
# Nick Nolte
# Nicolas Cage
# Oliver Platt
# Paul Giamatti
# Philip Seymour Hoffman
# Ray Liotta
# Richard Dreyfuss
# Richard Jenkins
# Robert De Niro
# Robert Downey Jr.
# Robert Duvall
# Robin Williams
# Samuel L. Jackson
# Sean Connery
# Sigourney Weaver
# Stanley Tucci
# Stephen Root
# Stephen Tobolowsky
# Steve Buscemi
# Steve Martin
# Susan Sarandon
# Sylvester Stallone
# Tom Hanks
# Tom Wilkinson
# Tommy Lee Jones
# Val Kilmer
# Ving Rhames
# Wallace Shawn
# Whoopi Goldberg
# Willem Dafoe
# William H. Macy
# Woody Harrelson

# %% [markdown]
# Even with this filter, we still have a high number of actor (113). This is still a high number and if we want to test every pair of actor as a independant variable, we need (113*112)/2 beta. We still have the possibility to filter more using maybe more qualitative aspect.

# %% [markdown]
# An important aspect that we have to care about is the interaction between actors. We build now the matrix of interraction between actors with more than 25 films. (Why 25? because it is better to have a bigger number of actor)

# %%
actors_to_drop=actor_sum[actor_sum<25].index

filtered_binary_matrix=binary_matrix.drop(actors_to_drop,axis=1)

filtered_binary_matrix
# Out:
#                          Adam Sandler  Adrien Brody  Aidan Quinn  Al Pacino  \
# Name
# 'Til There Was You                  0             0            0          0
# (500) Days of Summer                0             0            0          0
# *batteries not included             0             0            0          0
# ...And Justice for All              0             0            0          1
# 10                                  0             0            0          0
# ...                               ...           ...          ...        ...
# Zoom                                0             0            0          0
# Zoot Suit                           0             0            0          0
# ¡Three Amigos!                      0             0            0          0
# Æon Flux                            0             0            0          0
# Žižek!                              0             0            0          0
#
#                          Alan Arkin  Alan Cumming  Alan Rickman  Alec Baldwin  \
# Name
# 'Til There Was You                0             0             0             0
# (500) Days of Summer              0             0             0             0
# *batteries not included           0             0             0             0
# ...And Justice for All            0             0             0             0
# 10                                0             0             0             0
# ...                             ...           ...           ...           ...
# Zoom                              0             0             0             0
# Zoot Suit                         0             0             0             0
# ¡Three Amigos!                    0             0             0             0
# Æon Flux                          0             0             0             0
# Žižek!                            0             0             0             0
#
#                          Alfred Molina  Allison Janney  ...  Whoopi Goldberg  \
# Name                                                    ...
# 'Til There Was You                   0               0  ...                0
# (500) Days of Summer                 0               0  ...                0
# *batteries not included              0               0  ...                0
# ...And Justice for All               0               0  ...                0
# 10                                   0               0  ...                0
# ...                                ...             ...  ...              ...
# Zoom                                 0               0  ...                0
# Zoot Suit                            0               0  ...                0
# ¡Three Amigos!                       0               0  ...                0
# Æon Flux                             0               0  ...                0
# Žižek!                               0               0  ...                0
#
#                          Will Ferrell  Will Patton  Willem Dafoe  \
# Name
# 'Til There Was You                  0            0             0
# (500) Days of Summer                0            0             0
# *batteries not included             0            0             0
# ...And Justice for All              0            0             0
# 10                                  0            0             0
# ...                               ...          ...           ...
# Zoom                                0            0             0
# Zoot Suit                           0            0             0
# ¡Three Amigos!                      0            0             0
# Æon Flux                            0            0             0
# Žižek!                              0            0             0
#
#                          William H. Macy  William Hurt  Winona Ryder  \
# Name
# 'Til There Was You                     0             0             0
# (500) Days of Summer                   0             0             0
# *batteries not included                0             0             0
# ...And Justice for All                 0             0             0
# 10                                     0             0             0
# ...                                  ...           ...           ...
# Zoom                                   0             0             0
# Zoot Suit                              0             0             0
# ¡Three Amigos!                         0             0             0
# Æon Flux                               0             0             0
# Žižek!                                 0             0             0
#
#                          Woody Allen  Woody Harrelson  Xander Berkeley
# Name
# 'Til There Was You                 0                0                0
# (500) Days of Summer               0                0                0
# *batteries not included            0                0                0
# ...And Justice for All             0                0                0
# 10                                 0                0                0
# ...                              ...              ...              ...
# Zoom                               0                0                0
# Zoot Suit                          0                0                0
# ¡Three Amigos!                     0                0                0
# Æon Flux                           0                0                0
# Žižek!                             0                0                0
#
# [8022 rows x 367 columns]

# %% [markdown]
# For each column of the filtered_binary_matrix, we multiply by every other column and them sum the new column

# %%
binary_matrix_column = filtered_binary_matrix.columns


matrix = np.zeros([len(binary_matrix_column),len(binary_matrix_column)])

i = 0
j = 0
# Iteration in every row and column to calculate the interaction
for col in binary_matrix_column:
    result = []
    j = 0
    for col2 in binary_matrix_column:
        #since the column are dummies, we can just multiply
        matrix[i,j]= (filtered_binary_matrix[col]* filtered_binary_matrix[col2]).sum()
        j+= 1
    i+=1

# We put the result in a dataframe
pairing_df = pd.DataFrame(matrix, columns=binary_matrix_column, index=binary_matrix_column)

# We save the result in a csv file
pairing_df.to_csv('interaction_matrix_actors.csv', index=False)

# %% [markdown]
# We have our matrix of interaction. We will sort a list of actor that interract the most with his pear. We set the diagonal of the matrix equal to 0 and count the number of interaction of each actor

# %%
matrix_interaction = matrix - matrix*np.eye(len(binary_matrix_column))
pure_interaction = pd.DataFrame(matrix_interaction, columns=binary_matrix_column, index=binary_matrix_column)

pure_interaction = pure_interaction.sum(axis =1)

pure_interaction.sort_values(ascending=False)
# Out:
# Steve Buscemi        200.0
# Samuel L. Jackson    179.0
# Hank Azaria          173.0
# Bruce Willis         166.0
# Tom Hanks            163.0
#                      ...
# Keenan Wynn           18.0
# Katharine Hepburn     15.0
# James Mason           14.0
# James Stewart         12.0
# Ginger Rogers          5.0
# Length: 367, dtype: float64

# %% [markdown]
# Now we have a list of actors who collaborate most frequently with their peers.

# %% [markdown]
# Additional Idea : We should maybe draw a map of the connection between actor to get rid of interration between actor that have never worked together. We should maybe add more women (even if their number of film is lower). We could maybe see an intresting trend
# We could also use other types of variable such as the age difference between the actors

# %%
#let's try to create a graph network
import networkx as nx
import matplotlib.pyplot as plt

#create a mapping from actor names to numbers (for better visualization)
actor_to_number = {actor: num for num, actor in enumerate(pairing_df.columns)}

#create a graph
G = nx.from_pandas_adjacency(pairing_df)
G = nx.relabel_nodes(G, actor_to_number)

# %%
#lets fix a treshold to remove the edges with a low interaction in order to have a better visualization
threshold = 50 #we can change this value to see the difference  
for u, v, d in list(G.edges(data=True)):
    if d['weight'] <= threshold:
        G.remove_edge(u, v)

# %%
#plot the graph
import matplotlib.pyplot as plt

pos = nx.spring_layout(G, scale=2)  # positions for all nodes
#weights = [G[u][v]['weight'] for u, v in G.edges()]
edge_widths = [d['weight'] for u, v, d in G.edges(data=True)]  

#nx.draw(G, pos, edges=G.edges(), width=weights, with_labels=True, node_size=50, font_size=8)
nx.draw(G, pos, width=edge_widths, with_labels=True, node_size=70, font_size=12, alpha=0.7)

#adjust the label position
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=5)

plt.show()

# %%
filtered_binary_matrix = filtered_binary_matrix.copy()

#instead of having one or zero indicating if the actor played in the correponding movie, 
#we will indicate his age at movie release 
age_matrix = filtered_binary_matrix

# %%
for name in age_matrix.index:
    for col in age_matrix.columns:
        if age_matrix.at[name, col] == 1 :
            age_matrix.at[name, col] = df_count.loc[(df_count['Actor Name']== col) & (df_count['Name']== name)]['Actor Age At Movie Release'].values[0]

age_matrix.head(5)
# Out:
#                          Adam Sandler  Adrien Brody  Aidan Quinn  Al Pacino  \
# Name
# 'Til There Was You                  0           0.0            0        0.0
# (500) Days of Summer                0           0.0            0        0.0
# *batteries not included             0           0.0            0        0.0
# ...And Justice for All              0           0.0            0       39.0
# 10                                  0           0.0            0        0.0
#
#                          Alan Arkin  Alan Cumming  Alan Rickman  Alec Baldwin  \
# Name
# 'Til There Was You              0.0             0             0           0.0
# (500) Days of Summer            0.0             0             0           0.0
# *batteries not included         0.0             0             0           0.0
# ...And Justice for All          0.0             0             0           0.0
# 10                              0.0             0             0           0.0
#
#                          Alfred Molina  Allison Janney  ...  Whoopi Goldberg  \
# Name                                                    ...
# 'Til There Was You                 0.0             0.0  ...                0
# (500) Days of Summer               0.0             0.0  ...                0
# *batteries not included            0.0             0.0  ...                0
# ...And Justice for All             0.0             0.0  ...                0
# 10                                 0.0             0.0  ...                0
#
#                          Will Ferrell  Will Patton  Willem Dafoe  \
# Name
# 'Til There Was You                  0          0.0           0.0
# (500) Days of Summer                0          0.0           0.0
# *batteries not included             0          0.0           0.0
# ...And Justice for All              0          0.0           0.0
# 10                                  0          0.0           0.0
#
#                          William H. Macy  William Hurt  Winona Ryder  \
# Name
# 'Til There Was You                   0.0             0           0.0
# (500) Days of Summer                 0.0             0           0.0
# *batteries not included              0.0             0           0.0
# ...And Justice for All               0.0             0           0.0
# 10                                   0.0             0           0.0
#
#                          Woody Allen  Woody Harrelson  Xander Berkeley
# Name
# 'Til There Was You               0.0              0.0              0.0
# (500) Days of Summer             0.0              0.0              0.0
# *batteries not included          0.0              0.0              0.0
# ...And Justice for All           0.0              0.0              0.0
# 10                               0.0              0.0              0.0
#
# [5 rows x 367 columns]

# %%
#check
age_matrix.loc[age_matrix['Adam Sandler']==41]['Adam Sandler']
# Out:
# Name
# You Don't Mess with the Zohan    41
# Name: Adam Sandler, dtype: int64

# %%
#matrix_age_difference = {'Movies': [] , 'Actor1': [], 'Actor2': [], 'Age difference': []}
#matrix_age_difference = pd.DataFrame(data = matrix_age_difference)

# Iteration in every row and column to calculate the interaction
#for name in age_matrix.index:
    #for col1 in age_matrix.columns:
        #for col2 in age_matrix.columns:
            #if (age_matrix.at[name, col1] !=0) & (age_matrix.at[name, col2] !=0) :
                #age_difference = abs(age_matrix.at[name, col2] - age_matrix.at[name, col1])
                #list_row = [name, col1, col2, age_difference ]
                #matrix_age_difference.loc[len(matrix_age_difference)] = list_row


#matrix_age_difference.head(5)

# %%
# First linear regression 
data_regression_revenue_actors = filtered_binary_matrix
revenue = []
for name in data_regression_revenue_actors.index:
    revenue.append(df_count.loc[df_count['Name']==name]['Revenue'].iloc[0])
data_regression_revenue_actors['Revenue'] = revenue


data_regression_revenue_actors.head(5)
# Out:
# /var/folders/bn/ds_wr8111z3c4d9rq_nhk1dw0000gn/T/ipykernel_30841/1119639274.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_regression_revenue_actors['Revenue'] = revenue
#                          Adam Sandler  Adrien Brody  Aidan Quinn  Al Pacino  \
# Name
# 'Til There Was You                  0           0.0            0        0.0
# (500) Days of Summer                0           0.0            0        0.0
# *batteries not included             0           0.0            0        0.0
# ...And Justice for All              0           0.0            0       39.0
# 10                                  0           0.0            0        0.0
#
#                          Alan Arkin  Alan Cumming  Alan Rickman  Alec Baldwin  \
# Name
# 'Til There Was You              0.0             0             0           0.0
# (500) Days of Summer            0.0             0             0           0.0
# *batteries not included         0.0             0             0           0.0
# ...And Justice for All          0.0             0             0           0.0
# 10                              0.0             0             0           0.0
#
#                          Alfred Molina  Allison Janney  ...  Will Ferrell  \
# Name                                                    ...
# 'Til There Was You                 0.0             0.0  ...             0
# (500) Days of Summer               0.0             0.0  ...             0
# *batteries not included            0.0             0.0  ...             0
# ...And Justice for All             0.0             0.0  ...             0
# 10                                 0.0             0.0  ...             0
#
#                          Will Patton  Willem Dafoe  William H. Macy  \
# Name
# 'Til There Was You               0.0           0.0              0.0
# (500) Days of Summer             0.0           0.0              0.0
# *batteries not included          0.0           0.0              0.0
# ...And Justice for All           0.0           0.0              0.0
# 10                               0.0           0.0              0.0
#
#                          William Hurt  Winona Ryder  Woody Allen  \
# Name
# 'Til There Was You                  0           0.0          0.0
# (500) Days of Summer                0           0.0          0.0
# *batteries not included             0           0.0          0.0
# ...And Justice for All              0           0.0          0.0
# 10                                  0           0.0          0.0
#
#                          Woody Harrelson  Xander Berkeley     Revenue
# Name
# 'Til There Was You                   0.0              0.0   3525125.0
# (500) Days of Summer                 0.0              0.0  60722734.0
# *batteries not included              0.0              0.0  65088797.0
# ...And Justice for All               0.0              0.0  33300000.0
# 10                                   0.0              0.0  74865517.0
#
# [5 rows x 368 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

n = len(data_regression_revenue_actors.columns)-1
X = data_regression_revenue_actors.iloc[:,:n] #to get the first columns before the last
y = data_regression_revenue_actors.iloc[ :, -1:] #to get last column


X = X.fillna(0)

#Revenue = beta_i*actor_i + epsilon
#sm.OLS(y,X).fit().summary()
